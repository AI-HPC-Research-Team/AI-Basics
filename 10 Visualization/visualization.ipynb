# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/AI-HPC-Research-Team/AI-Basics/blob/main/10%20Visualization/visualization.ipynb)
# # Visualization: A Practical Notebook
#
# This notebook is organised into three teaching modules:
# 1. **Omics** - how to load a tiny real gene expression dataset, visualize global patterns with PCA and clustered heatmaps, and quantify gene–gene relationships with correlation matrices and co-expression networks.
# 2. **Proteins** – how to work with 3D protein structures, build contact maps, and use interactive 3D viewers.
# 3. **Small molecules** – how to represent molecules with SMILES, fingerprints and scaffolds, and how to explore their chemical space.

# %%
# !pip -qq install numpy matplotlib Biopython wget nglview "ipywidgets>=8.1.0" scaffoldgraph[rdkit,vis] chemplot py3Dmol scikit-learn scaffoldgraph adjustText  gdown
from google.colab import output
output.enable_custom_widget_manager()
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.2/26.2 MB 82.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# WARNING: scaffoldgraph 1.1.1 does not provide the extra 'rdkit'
# WARNING: scaffoldgraph 1.1.1 does not provide the extra 'vis'
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 88.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.1/780.1 kB 44.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 106.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 106.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 81.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.0/176.0 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 15.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 65.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 4.6 MB/s eta 0:00:00
#   Building wheel for wget (setup.py) ... done
#   Building wheel for nglview (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-kernel-gateway 2.5.2 requires notebook<7.0,>=5.7.6, but you have notebook 7.5.1 which is incompatible.

# %% [markdown]
# ## Part 1 – Omics Visualization
#
# This part adds **fully runnable** omics visualization demos using **tiny subset** from GEO: **GSE52778** (human airway smooth muscle; Dex vs untreated):
# - Heatmap (with hierarchical clustering)
# - Volcano plot (differential expression)
# - PCA (dimensionality reduction)
# - Correlation matrix + co-expression network
# - Time-series expression curves
# - Mini single-cell demo (sparse / dropout-like matrix)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy import stats
from scipy.cluster.hierarchy import linkage, leaves_list
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import networkx as nx

np.random.seed(42)

# %% [markdown]
# ### 1.1 Tiny Bulk RNA-seq–like Matrix (Counts → logCPM)
#
# We automatically pick a small number of highly variable genes so everything runs fast in class.

# %%
# ---- Load real bulk RNA-seq expression from GEO (GSE52778) ----
# Source (processed expression matrix):
# https://ftp.ncbi.nlm.nih.gov/geo/series/GSE52nnn/GSE52778/suppl/GSE52778_All_Sample_FPKM_Matrix.txt.gz

import re
import pandas as pd
import numpy as np

GEO_FPKM_URL = "https://ftp.ncbi.nlm.nih.gov/geo/series/GSE52nnn/GSE52778/suppl/GSE52778_All_Sample_FPKM_Matrix.txt.gz"

# Read the full processed matrix (small ~2.5MB)
raw = pd.read_csv(GEO_FPKM_URL, sep=" ", compression="gzip", low_memory=False)
raw.columns = [str(c).strip() for c in raw.columns]


gene_col = "gene_id"

raw = raw.dropna(subset=[gene_col]).copy()
raw[gene_col] = raw[gene_col].astype(str)

# We will demonstrate a simple 2-group comparison: Dex vs untreated (4 donors => 8 samples)

# Candidate expression columns: anything containing one of the sample patterns
candidate_cols = ["Dex_LL14","Dex_LL06","Dex_LL02","Dex_LL10","Untreated_LL09","Untreated_LL05","Untreated_LL13","Untreated_LL01"]
if len(candidate_cols) == 0:
    raise ValueError(
        "Could not find sample columns in the GEO matrix. "
        "Try printing raw.columns to inspect the header structure."
    )

def score_col(colname: str) -> int:
    # Prefer columns that explicitly look like FPKM measurements
    s = 0
    if re.search(r"fpkm", colname, flags=re.IGNORECASE):
        s += 3
    if re.search(r"\bfpkm\b", colname, flags=re.IGNORECASE):
        s += 1
    return s


expr = raw[[gene_col] + candidate_cols].copy()

# If duplicated gene symbols exist, average them (tiny demo simplification)
expr = expr.groupby(gene_col, as_index=False).mean(numeric_only=True)
expr = expr.set_index(gene_col)

# Make sure everything is numeric
expr = expr.apply(pd.to_numeric, errors="coerce").fillna(0.0)

# Rename columns to clean sample names when possible
col_map = {col: p for p, col in best.items()}
expr = expr.rename(columns=col_map)

# Build metadata (Control = untreated, Treatment = Dex)
samples = list(expr.columns)
group = []
for s in samples:
    if str(s).startswith("Dex"):
        group.append("Treatment")
    elif str(s).startswith("Untreated"):
        group.append("Control")
    else:
        # In case extra columns slipped in (fallback), mark as Unknown
        group.append("Unknown")

meta_df = pd.DataFrame({"sample": samples, "group": np.array(group)}).set_index("sample")

# Keep only Control/Treatment samples (drop Unknown if any)
keep = meta_df.index[meta_df["group"].isin(["Control", "Treatment"])].tolist()
expr = expr.loc[:, keep]
meta_df = meta_df.loc[keep]

# ---- Auto tiny subset: pick top-K variable genes so plots are fast ----
# Use log1p variance as a simple variability measure
log_expr = np.log1p(expr)
top_k = 50
top_genes = log_expr.var(axis=1).sort_values(ascending=False).head(top_k).index

counts_df = expr.loc[top_genes].copy()

# Shared variables used by downstream demo cells
genes = counts_df.index.tolist()
samples = counts_df.columns.tolist()
group = meta_df.loc[samples, "group"].values

n_genes = len(genes)
n_samples = len(samples)

counts_df.iloc[:5, :8], meta_df.head()
# Out:
# (         Dex_LL14  Dex_LL06  Dex_LL02  Dex_LL10  Untreated_LL09  \
#  gene_id
#  FTL       8060.93   9516.86  10510.90  11109.30        0.000000
#  SNORD34      0.00   5936.84      0.00   7043.24        0.000000
#  SNORD29      0.00  10625.80      0.00  25212.00        0.573054
#  MIR24-1   2612.41   5108.62   4736.04   9091.01        1.095540
#  QSOX1        0.00      0.00      0.00      0.00     2895.650000
#
#           Untreated_LL05  Untreated_LL13  Untreated_LL01
#  gene_id
#  FTL            0.000000            0.00            0.00
#  SNORD34        0.000000            0.00         7103.66
#  SNORD29        1.260860            0.00            0.00
#  MIR24-1        0.602619            0.00            0.00
#  QSOX1       3173.120000         2968.14         3592.97  ,
#                      group
#  sample
#  Dex_LL14        Treatment
#  Dex_LL06        Treatment
#  Dex_LL02        Treatment
#  Dex_LL10        Treatment
#  Untreated_LL09    Control)

# %%
# ---- Normalize for visualization: since this is already FPKM, we use log1p(FPKM) ----
logcpm = np.log1p(counts_df)

logcpm.iloc[:5, :5]
# Out:
#          Dex_LL14  Dex_LL06  Dex_LL02   Dex_LL10  Untreated_LL09
# gene_id
# FTL      8.994908  9.160925  9.260263   9.315628        0.000000
# SNORD34  0.000000  8.689101  0.000000   8.859966        0.000000
# SNORD29  0.000000  9.271134  0.000000  10.135115        0.453019
# MIR24-1  7.868411  8.538880  8.463168   9.115151        0.739811
# QSOX1    0.000000  0.000000  0.000000   0.000000        7.971310

# %% [markdown]
# ### 1.2 Heatmap + Hierarchical Clustering (Genes × Samples)
#
# We cluster **samples** and **genes** using correlation distance, then plot a compact heatmap.

# %%
# ---- Cluster rows (genes) and columns (samples) ----
X = logcpm.values

# Linkage on genes and samples using correlation distance
gene_link = linkage(X, method="average", metric="correlation")
samp_link = linkage(X.T, method="average", metric="correlation")

gene_order = leaves_list(gene_link)
samp_order = leaves_list(samp_link)

X_reordered = X[gene_order][:, samp_order]
genes_reordered = [genes[i] for i in gene_order]
samples_reordered = [samples[i] for i in samp_order]

plt.figure(figsize=(6, 6))
plt.imshow(X_reordered, aspect="auto")
plt.colorbar(label="log1p(FPKM)")
plt.xticks(range(len(samples_reordered)), samples_reordered, rotation=90)
plt.yticks(range(len(genes_reordered)), genes_reordered, fontsize=6)
plt.title("GSE52778 Heatmap (Dex vs untreated) — tiny subset")
plt.tight_layout()
plt.show()

meta_df.loc[samples_reordered]
# Out:
#                     group
# sample
# Dex_LL06        Treatment
# Dex_LL10        Treatment
# Dex_LL14        Treatment
# Dex_LL02        Treatment
# Untreated_LL13    Control
# Untreated_LL01    Control
# Untreated_LL09    Control
# Untreated_LL05    Control

# %% [markdown]
# ### 1.3 Volcano Plot (Differential Expression)
#
# We do a quick **t-test** per gene (Control vs Treatment) and show log2 fold-change vs −log10(p).

# %%
# ---- Differential expression (simple t-test on log1p(FPKM)) ----
ctrl = logcpm.loc[:, meta_df.index[meta_df["group"] == "Control"]]
treat = logcpm.loc[:, meta_df.index[meta_df["group"] == "Treatment"]]

# Difference of means on ln-scale, converted to log2 scale (demo approximation)
log2fc = (treat.mean(axis=1) - ctrl.mean(axis=1)) / np.log(2)
pvals = np.array([stats.ttest_ind(treat.loc[g], ctrl.loc[g], equal_var=False).pvalue for g in genes])

volcano = pd.DataFrame({"gene": genes, "log2FC": log2fc.values, "pval": pvals}).set_index("gene")
volcano["neglog10p"] = -np.log10(np.clip(volcano["pval"], 1e-300, 1.0))

# Pick top genes to label
top_to_label = volcano.sort_values("neglog10p", ascending=False).head(10).index.tolist()

# Also keep "top up/down" gene lists for quick discussion
de_up = volcano.sort_values(["log2FC", "neglog10p"], ascending=[False, False]).head(5).index.tolist()
de_down = volcano.sort_values(["log2FC", "neglog10p"], ascending=[True, False]).head(5).index.tolist()

plt.figure(figsize=(7, 5))
plt.scatter(volcano["log2FC"], volcano["neglog10p"], s=25)

for g in top_to_label:
    x, y = volcano.loc[g, ["log2FC", "neglog10p"]]
    plt.text(x, y, g, fontsize=8)

plt.axvline(1.0, linestyle="--")
plt.axvline(-1.0, linestyle="--")
plt.axhline(1.3, linestyle="--")  # ~ p=0.05
plt.xlabel("log2 Fold Change (Dex vs untreated)")
plt.ylabel("-log10(p-value)")
plt.title("Volcano Plot (GSE52778 tiny subset)")
plt.tight_layout()
plt.show()

print("Top up (by log2FC):", de_up)
print("Top down (by log2FC):", de_down)
# Out:
# Top up (by log2FC): ['FTL', 'MIR24-1', 'COL1A2', 'SNORD36A', 'SNORD68']
# Top down (by log2FC): ['QSOX1', 'MIR3189', 'MIR4701', 'FLJ23867', 'MIR93']

# %% [markdown]
# ### 1.4 PCA (Samples in 2D)
#
# PCA is a standard way to check overall structure / batch effects on high-dimensional omics matrices.

# %%
# ---- PCA on samples ----
X_samp = logcpm.T.values  # samples × genes
X_samp_scaled = StandardScaler().fit_transform(X_samp)

pca = PCA(n_components=2, random_state=42)
Z = pca.fit_transform(X_samp_scaled)

plt.figure(figsize=(6, 5))
for grp in ["Control", "Treatment"]:
    idx = (group == grp)
    plt.scatter(Z[idx, 0], Z[idx, 1], label=grp, s=60)

for i, s in enumerate(samples):
    plt.text(Z[i, 0], Z[i, 1], s, fontsize=8)

plt.xlabel(f"PC1 ({pca.explained_variance_ratio_[0]*100:.1f}%)")
plt.ylabel(f"PC2 ({pca.explained_variance_ratio_[1]*100:.1f}%)")
plt.title("PCA of samples (logCPM)")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.5 Correlation Matrix + Co-expression Network
#
# We compute gene–gene correlations and build a tiny network by thresholding |corr| ≥ 0.85.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

genes = logcpm.index.to_list()          # Gene names (row names)
corr = np.corrcoef(logcpm.values)       # genes × genes
corr_df = pd.DataFrame(corr, index=genes, columns=genes)

g = sns.clustermap(
    corr_df,
    vmin=-1, vmax=1, cmap="vlag",
    method="average",
    figsize=(8, 8),
    xticklabels=True, yticklabels=True  # Show gene names
)

# Styling: rotate and resize labels to avoid overcrowding
g.ax_heatmap.set_xticklabels(g.ax_heatmap.get_xticklabels(), rotation=90, fontsize=6)
g.ax_heatmap.set_yticklabels(g.ax_heatmap.get_yticklabels(), rotation=0, fontsize=6)

plt.show()


# ---- Build a simple co-expression network ----
thr = 0.85
G = nx.Graph()
G.add_nodes_from(genes)

for i in range(n_genes):
    for j in range(i + 1, n_genes):
        if abs(corr[i, j]) >= thr:
            G.add_edge(genes[i], genes[j], weight=float(corr[i, j]))

print("Nodes:", G.number_of_nodes(), "Edges:", G.number_of_edges())

# Plot a readable subgraph: keep top-degree nodes
deg = dict(G.degree())
top_nodes = sorted(deg, key=deg.get, reverse=True)[:15]
H = G.subgraph(top_nodes).copy()

plt.figure(figsize=(7, 5))
pos = nx.spring_layout(H, seed=42)
nx.draw_networkx_nodes(H, pos, node_size=300)
nx.draw_networkx_edges(H, pos, width=1.2)
nx.draw_networkx_labels(H, pos, font_size=8)
plt.title(f"Co-expression network (top 15 genes, |r|≥{thr})")
plt.axis("off")
plt.tight_layout()
plt.show()
# Out:
# Nodes: 50 Edges: 98

# %% [markdown]
# ## Part 2 – Protein Structures and Contact Maps
#
# In this part we will:
#
# - Import standard scientific Python tools and structure-handling libraries.
# - Load a protein structure from a PDB file.
# - Extract Cα coordinates and compute a pairwise distance matrix.
# - Convert the distance matrix into a binary **contact map** under a given cut-off.
# - Plot the contact map and relate it back to the 3D structure (e.g. using nglview or similar tools).
#
# The key idea is that a protein can be described both as a 3D object in space and as a 2D matrix of residue–residue contacts.

# %%
import Bio.PDB, numpy as np, matplotlib.pyplot as plt
import os, wget

os.makedirs("data", exist_ok=True)
os.makedirs("figure", exist_ok=True)
# download a PDB file from the RCSB PDB database
wget.download("https://files.rcsb.org/download/1UBQ.pdb", "./data/1ubq.pdb")
parser = Bio.PDB.PDBParser()

structure = parser.get_structure("1UBQ", "./data/1ubq.pdb")  # e.g., ubiquitin
# Extract Cα atom coordinates for all residues:
coords = [atom.get_coord() for atom in structure.get_atoms() if atom.get_name() == "CA"]
coords = np.array(coords)
dist_matrix = np.linalg.norm(coords[:, None, :] - coords[None, :, :], axis=-1)
contact_map = dist_matrix < 8.0  # boolean matrix of contacts under 8Å

plt.imshow(contact_map, cmap="Greys", origin="lower")
plt.title("Contact Map of 1UBQ (Ubiquitin)")
plt.savefig("./figure/contact_map.png")

# %%
import nglview as nv

# Load a structure (by PDB ID or local file)
# view = nv.show_pdbid("1TUP")        # p53 core domain structure from PDB
view = nv.show_file("./data/1ubq.pdb")  # load local AlphaFold model for p53
view.representations = [{"type": "cartoon", "params": {"color": "residueindex"}}]
view

# %% [markdown]
# ## Part 3 – Small-Molecule Representations and Chemical Space
#
# Now we switch from protein structures to **small molecules**. In this part we will:
#
# - Install and import **RDKit** and other chemistry tools.
# - Convert SMILES strings to canonical forms.
# - Compute simple fingerprints such as **MACCS keys**.
# - Generate 2D drawings and basic 3D conformers.
# - Visualise a small set of molecules in **chemical space** using dimensionality reduction.
# - Take a first look at scaffolds and scaffold networks.
#
# Again, try to connect the code to the concepts: molecular graphs, fingerprints, similarity, and the geometry of conformers.

# %%
from rdkit import Chem

mol = Chem.MolFromSmiles("OC(=O)C1=CC=CC=C1OC(=O)C")
canonical = Chem.MolToSmiles(mol, canonical=True)
print(canonical)  # Output: CC(=O)Oc1ccccc1C(=O)O

# %%
from rdkit import Chem
from rdkit.Chem import MACCSkeys

# Read a molecule, e.g. benzene
smiles = 'c1ccccc1'
mol = Chem.MolFromSmiles(smiles)

# Compute MACCS keys
maccs_fp = MACCSkeys.GenMACCSKeys(mol)

# Output as a bit vector
print(maccs_fp)                # print directly
print(list(maccs_fp))          # convert to a list (vector of 0/1)
print(maccs_fp.GetNumBits())   # check length (typically 167 bits; bit 0 unused)

# %%
from rdkit.Chem import AllChem
from rdkit.Chem import Draw
from rdkit.Chem import rdMolAlign

# Generate 3D conformer for aspirin
aspirin_smiles = "CC(=O)Oc1ccccc1C(=O)O"  # Aspirin SMILES
mol = Chem.MolFromSmiles(aspirin_smiles)
mol = Chem.AddHs(mol)
AllChem.EmbedMolecule(mol, AllChem.ETKDG())
AllChem.UFFOptimizeMolecule(mol)


# Generate image from 3D conformer
img_3d = Draw.MolToImage(mol, size=(300, 300), legend="Aspirin 3D (conformer)")
image_path_3d = "./figure/aspirin_3d.png"
img_3d.save(image_path_3d)
mol.GetConformer(0).GetPositions()

# %%
img_3d

# %%
from rdkit import Chem, DataStructs
from rdkit.Chem import AllChem
from sklearn.decomposition import PCA
import numpy as np
from matplotlib import pyplot as plt

def fp2arr(fp):
    arr = np.zeros((1,))
    DataStructs.ConvertToNumpyArray(fp, arr)
    return arr

# Define molecules with names
molecules = {
    "Aspirin": "CC(=O)Oc1ccccc1C(=O)O",
    "Celecoxib": "CC1=CC=C(C=C1)C2=CC("+ \
        "=NN2C3=CC=C(C=C3)S(=O)(=O)N)C(F)(F)F",
    "Benzene": "C1=CC=CC=C1",
    "Ibuprofen": "CC(C)CC1=CC=C(C=C1)C(C)C(=O)O",
    "Nicotine": "CN1CCC[C@H]1C2=CN=CC=C2",
    "Salbutamol": "CC(C)(C)NCC(C1=CC(=C(C=C1)O)CO)O"
}

# Compute fingerprints
fps = [AllChem.GetMorganFingerprintAsBitVect(
        Chem.MolFromSmiles(smiles), 2, 1024)
     for smiles in molecules.values()]
arr = np.array([fp2arr(fp) for fp in fps])

# Perform PCA
pca = PCA(n_components=2)
res = pca.fit_transform(arr)
pc = res.T

# Plot
plt.figure(figsize=(8, 6))
plt.scatter(pc[0], pc[1], marker="o",
    color='skyblue', edgecolors='k')

# Annotate points
for i, name in enumerate(molecules.keys()):
    plt.text(pc[0][i] + 0.02, pc[1][i], name, fontsize=9)

cum_cr = sum(pca.explained_variance_ratio_)
plt.title("Chemical Space Map (PCA on" + \
    "Morgan Fingerprints)\n" + \
    "Cumulative Variance Explained = %.2f" % cum_cr)
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.grid(True)
plt.tight_layout()

img_path = "./figure/pca_plot_annotated.png"
plt.savefig(img_path)
plt.show()
img_path

# %%
from chemplot import Plotter
from matplotlib import pyplot as plt

# Define molecules
molecules = {
    "Aspirin": "CC(=O)Oc1ccccc1C(=O)O",
    "Celecoxib": "CC1=CC=C(C=C1)C2=CC(=NN2C3=CC=C(C=C3)S(=O)(=O)N)C(F)(F)F",
    "Benzene": "C1=CC=CC=C1",
    "Ibuprofen": "CC(C)CC1=CC=C(C=C1)C(C)C(=O)O",
    "Nicotine": "CN1CCC[C@H]1C2=CN=CC=C2",
    "Salbutamol": "CC(C)(C)NCC(C1=CC(=C(C=C1)O)CO)O"
}
smiles_list = list(molecules.values())
labels = list(molecules.keys())

# Generate Chemplot PCA map
cp = Plotter.from_smiles(smiles_list)
coords = cp.pca()

# Plot with annotations
plt.figure(figsize=(8, 6))
plt.scatter(coords.iloc[:, 0], coords.iloc[:, 1], color='skyblue', edgecolors='k')

# Add text labels
for i, name in enumerate(labels):
    plt.text(coords.iloc[i, 0] + 0.02, coords.iloc[i, 1], name, fontsize=9)

plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("Chemical Space Map (PCA via Chemplot)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import os
os.makedirs("./data", exist_ok=True)

import math
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import networkx as nx
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem import rdDepictor

rdDepictor.SetPreferCoordGen(True)  # nicer 2D coordinates for depiction

# ---- 1) Collect each node's SMILES and a short label ----
smiles_by_node = {}
labels = {}
for n, d in network.nodes(data=True):
    smi = d.get("smiles")  # ScaffoldGraph usually stores 'smiles' on nodes
    # Fallback: sometimes the node key itself is a SMILES string
    if smi is None and isinstance(n, str):
        try:
            if Chem.MolFromSmiles(n) is not None:
                smi = n
        except Exception:
            pass
    smiles_by_node[n] = smi

    # Use SMILES (truncated) as the label; fall back to node id
    label = smi if smi else str(n)
    labels[n] = (label[:21] + "...") if len(label) > 24 else label

# ---- 2) Compute a layout with extra spacing (to avoid overlap) ----
n_nodes = max(1, network.number_of_nodes())
# Larger k => nodes pushed further apart. Base on graph size to keep spacing reasonable.
k = 100 / math.sqrt(n_nodes)
pos = nx.spring_layout(network, seed=42, k=k, iterations=200)

# Helpful extents for dynamic label offsets
xs = [p[0] for p in pos.values()]
ys = [p[1] for p in pos.values()]
x_span = (max(xs) - min(xs)) or 1.0
y_span = (max(ys) - min(ys)) or 1.0

# ---- 3) Draw edges first (under everything) ----
fig, ax = plt.subplots(figsize=(10, 10))
nx.draw_networkx_edges(
    network, pos,
    width=2, alpha=0.8, edge_color="#999999", ax=ax, arrows=False
)

# ---- 4) Render each node as a 2D molecule image (instead of a dot) ----
def mol_image_from_smiles(smi, size=(140, 140)):
    """Return a PIL image for the SMILES; None if invalid."""
    if not smi:
        return None
    mol = Chem.MolFromSmiles(smi)
    if mol is None:
        return None
    rdDepictor.Compute2DCoords(mol)
    return Draw.MolToImage(mol, size=size)

# Tune these two to balance node size vs. overlap
img_size = (140, 140)
img_zoom = 0.33  # smaller = less overlap risk

for n, (x, y) in pos.items():
    img = mol_image_from_smiles(smiles_by_node.get(n), size=img_size)
    if img is not None:
        im = OffsetImage(img, zoom=img_zoom)
        # frameon=False ensures no bounding box around the image
        ab = AnnotationBbox(im, (x, y), frameon=False, pad=0.0, bboxprops=dict(alpha=0), zorder=3)
        ax.add_artist(ab)
    else:
        # Fallback: small dot if depiction failed
        ax.plot(x, y, "o", markersize=4, color="#1f77b4", zorder=3)

# ---- 5) Add labels below each image (offset computed from layout span) ----
# Use a vertical offset in data units so text does not cover the molecule image
label_y_offset = 0.06 * y_span  # increase if you still see overlap

for n, (x, y) in pos.items():
    ax.text(
        x, y - label_y_offset,
        labels[n],
        fontsize=7, ha="center", va="top", family="monospace",
        bbox=dict(boxstyle="round,pad=0.2", fc="white", ec="none", alpha=0.85),
        zorder=4,
        clip_on=False,  # allow label to extend outside axes if needed
    )

ax.axis("off")
plt.tight_layout()
plt.show()

# %%
import py3Dmol
import requests

# Download PDB file
pdb_id = '1OXR'
pdb_url = f'https://files.rcsb.org/download/{pdb_id}.pdb'
pdb_data = requests.get(pdb_url).text

# Visualization setup
view = py3Dmol.view(width=800, height=600)
view.addModel(pdb_data, 'pdb')

# Display protein chain A as cartoon
view.setStyle({'chain': 'A'}, {'cartoon': {'color': 'blue'}})

# Display ligand AIN as sticks
view.setStyle({'resn': 'AIN'}, {'stick': {'color': 'magenta'}})

# Display calcium ions (CA) as spheres
view.setStyle({'resn': 'CA'}, {'sphere': {'radius': 0.8, 'color': 'yellow'}})

# Optional: add a surface for the protein-ligand complex
view.addSurface(py3Dmol.VDW, {'opacity': 0.2})

# Zoom to the ligand region
view.zoomTo({'resn': 'AIN'})

# Render the viewer
view.show()

# %%
import matplotlib.pyplot as plt
from adjustText import adjust_text
from rdkit import Chem
from chemplot import Plotter
import wget

data_url = "https://github.com/AI-HPC-Research-Team/AI-Basics/raw/refs/heads/main/10 Visualization/data/NSAIDs.smi?raw=1"
wget.download(data_url, "./data/NSAIDs.smi")

# ---- Load data ---------------------------------------------------------------
smiles_list = [s.split(" ")[0] for s in open('./data/NSAIDs.smi')]
labels      = [s.split("#")[1].strip() for s in open('./data/NSAIDs.smi')]

cp     = Plotter.from_smiles(smiles_list)
coords = cp.umap(random_state=500)                      # compute UMAP coordinates
clusters =  cp.cluster(n_clusters=10)["clusters"]

X = coords.to_numpy()                        # (n_samples, 2)

# ---------- Identify one representative per cluster ----------
rep_indices = []          # store row-index of chosen molecules
for cid in np.unique(clusters):
    idx      = np.where(clusters == cid)[0]      # indices of points in this cluster
    cluster_pts = X[idx]                         # coordinates of those points
    centroid  = cluster_pts.mean(axis=0)         # 2-D centroid
    # choose point with smallest Euclidean distance to centroid
    rep_idx   = idx[np.linalg.norm(cluster_pts - centroid, axis=1).argmin()]
    rep_indices.append(rep_idx)

# ---------------- Plot with cluster colours ----------------
fig, ax = plt.subplots(figsize=(10, 10))
scatter = ax.scatter(X[:, 0], X[:, 1],
                     c=clusters, cmap='tab10', edgecolors='k', s=40)

# highlight representatives
for i in rep_indices:
    ax.scatter(X[i, 0], X[i, 1], s=250,
               facecolors='none', edgecolors='red', lw=2)
    ax.text(X[i, 0], X[i, 1]+2, labels[i],
            fontsize=20, weight='bold', color='red', ha='center', va='center')

ax.set_xlabel('UMAP-1')
ax.set_ylabel('UMAP-2')
ax.set_title('UMAP Chemical Space with 10 Clusters and Representatives')
plt.grid(True, ls='--', alpha=0.3)
plt.tight_layout()
plt.show()
